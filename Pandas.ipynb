# %%
#Importing the libraries
import numpy as np
import pandas as pd

# %%
#Creating Series
s=pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#Creating a Data Frame
data={'Name':['Alice','Bob','Cathy'],'Salary':[50000,60000,70000]}       #Creating Dict
df=pd.DataFrame(data)                                                    #Converting {data} into a DataFrame
df
# Out:
#     Name  Salary
# 0  Alice   50000
# 1    Bob   60000
# 2  Cathy   70000

# %%
#Data Visulization of a CSV file
data1=pd.read_csv('Bike Sales Data1.csv') #Importing a CSV file
df1=pd.DataFrame(data1)                   #Converting it into a DataFrame
df1
# Out:
#          ID Marital Status Gender      Income  Children            Education  \
# 0     12496              M      F  $40,000.00         1            Bachelors
# 1     24107              M      M  $30,000.00         3      Partial College
# 2     14177              M      M  $80,000.00         5      Partial College
# 3     24381              S      M  $70,000.00         0            Bachelors
# 4     25597              S      M  $30,000.00         0            Bachelors
# ...     ...            ...    ...         ...       ...                  ...
# 1021  16466              S      F  $20,000.00         0  Partial High School
# 1022  19273              M      F  $20,000.00         2      Partial College
# 1023  22400              M      M  $10,000.00         0      Partial College
# 1024  20942              S      F  $20,000.00         0          High School
# 1025  18484              S      M  $80,000.00         2          High School
#
# ...

# %%
#Data Visualization of a xlsx file
data2=pd.read_excel('Bike Sales Data.xlsx')      #Importing an EXCEL file
df2=pd.DataFrame(data2)                          #Converting it into a DataFrame
df2
# Out:
#          ID Marital Status Gender  Income  Children            Education  \
# 0     12496              M      F   40000         1            Bachelors
# 1     24107              M      M   30000         3      Partial College
# 2     14177              M      M   80000         5      Partial College
# 3     24381              S      M   70000         0            Bachelors
# 4     25597              S      M   30000         0            Bachelors
# ...     ...            ...    ...     ...       ...                  ...
# 1021  16466              S      F   20000         0  Partial High School
# 1022  19273              M      F   20000         2      Partial College
# 1023  22400              M      M   10000         0      Partial College
# 1024  20942              S      F   20000         0          High School
# 1025  18484              S      M   80000         2          High School
#
#           Occupation Home Owner  Cars Commute Distance   Region  Age  \
# ...

# %%
df1.head(10) #Usage of head function
# Out:
#       ID Marital Status Gender        Income  Children            Education  \
# 0  12496              M      F    $40,000.00         1            Bachelors
# 1  24107              M      M    $30,000.00         3      Partial College
# 2  14177              M      M    $80,000.00         5      Partial College
# 3  24381              S      M    $70,000.00         0            Bachelors
# 4  25597              S      M    $30,000.00         0            Bachelors
# 5  13507              M      F    $10,000.00         2      Partial College
# 6  27974              S      M  $1,60,000.00         2          High School
# 7  19364              M      M    $40,000.00         1            Bachelors
# 8  22155              M      M    $20,000.00         2  Partial High School
# 9  19280              M      M  $1,20,000.00         2      Partial College
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# ...

# %%
df1.tail(10) #Usage of tail function
# Out:
#          ID Marital Status Gender        Income  Children  \
# 1016  27184              S      M    $40,000.00         2
# 1017  12590              S      M    $30,000.00         1
# 1018  17841              S      M    $30,000.00         0
# 1019  18283              S      F  $1,00,000.00         0
# 1020  18299              M      M    $70,000.00         5
# 1021  16466              S      F    $20,000.00         0
# 1022  19273              M      F    $20,000.00         2
# 1023  22400              M      M    $10,000.00         0
# 1024  20942              S      F    $20,000.00         0
# 1025  18484              S      M    $80,000.00         2
#
#                 Education      Occupation Home Owner  Cars Commute Distance  \
# 1016      Partial College        Clerical         No     1        0-1 Miles
# 1017            Bachelors        Clerical        Yes     0        0-1 Miles
# 1018      Partial College        Clerical         No     1        0-1 Miles
# ...

# %%
df1.info() #Using info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1026 entries, 0 to 1025
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1026 non-null   int64
#  1   Marital Status    1026 non-null   object
#  2   Gender            1026 non-null   object
#  3   Income            1026 non-null   object
#  4   Children          1026 non-null   int64
#  5   Education         1026 non-null   object
#  6   Occupation        1026 non-null   object
#  7   Home Owner        1026 non-null   object
#  8   Cars              1026 non-null   int64
#  9   Commute Distance  1026 non-null   object
#  10  Region            1026 non-null   object
#  11  Age               1026 non-null   int64
#  12  Purchased Bike    1026 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 104.3+ KB

# %%
df1.describe() #Using Describe Function
# Out:
#                  ID     Children         Cars          Age
# count   1026.000000  1026.000000  1026.000000  1026.000000
# mean   19969.196881     1.892788     1.437622    44.138402
# std     5332.672942     1.626670     1.125538    11.349282
# min    11000.000000     0.000000     0.000000    25.000000
# 25%    15304.750000     0.000000     1.000000    35.000000
# 50%    19744.000000     2.000000     1.000000    43.000000
# 75%    24457.750000     3.000000     2.000000    52.000000
# max    29447.000000     5.000000     4.000000    89.000000

# %%
df1.shape #Checking shape
# Out:
# (1026, 13)

# %%
df1.columns #Retrieving columns
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %%
df1.dtypes #Checking datatype
# Out:
# ID                   int64
# Marital Status      object
# Gender              object
# Income              object
# Children             int64
# Education           object
# Occupation          object
# Home Owner          object
# Cars                 int64
# Commute Distance    object
# Region              object
# Age                  int64
# Purchased Bike      object
# dtype: object

# %%
df1.ndim #Checking dimension
# Out:
# 2
